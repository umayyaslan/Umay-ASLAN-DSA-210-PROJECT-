# %% [markdown]
# # 📊 Exploratory Data Analysis — Earthquake & Housing Sales
# ### DSA210 Project — Umay Aslan
#
# Purpose of this notebook:
# - Load the earthquake & housing data
# - Display first rows
# - Check missing values
# - Prepare for visualization & hypothesis testing
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

housing = pd.read_excel('../KONUT-DORT-SEHIR.xls')
quakes = pd.read_excel('../DEPREM-DORT-SEHIR.xlsx')

housing.head(), quakes.head()

# %% [markdown]
# ## 🔍 Column Overview

# %%
print(housing.columns.tolist())
print(quakes.columns.tolist())

# %% [markdown]
# ## 🧹 Missing Values

# %%
housing.isna().sum(), quakes.isna().sum()

# %% [markdown]
# ## 📅 Prepare Date Column (edit manually if needed)

# %%
# Replace 'Tarih' with your actual date column,
# e.g. housing['Date'] = pd.to_datetime(housing['Tarih'])
print('Notebook ready for visualization — next step: plotting 📈')
