# %% [markdown]
# # Earthquake Impact on Housing Sales — Exploratory Data Analysis
# ### DSA210 Course Project — Umay Aslan
#
# ---
# This notebook performs Exploratory Data Analysis (EDA) for the study:
# **"Do small-to-medium scale earthquakes (M4.0–6.0) significantly affect housing sales in Turkey's selected provinces?"**
#
# ### **Objectives of This Notebook**
# - Load datasets (Housing Sales + Earthquake Records)
# - Inspect dataset structure (columns, datatypes, missing values)
# - Prepare data for hypothesis testing and visualization
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

housing = pd.read_excel("../KONUT-DORT-SEHIR.xls")
earthquakes = pd.read_excel("../DEPREM-DORT-SEHIR.xlsx")

housing.head(), earthquakes.head()

# %% [markdown]
# ## 1. Dataset Overview
# A first look to understand structure and basic shape.

# %%
print("Housing dataset shape:", housing.shape)
print("Earthquake dataset shape:", earthquakes.shape)

housing.info()
earthquakes.info()

# %% [markdown]
# ## 2. Missing Value Check

# %%
housing.isna().sum(), earthquakes.isna().sum()

# %% [markdown]
# ## 3. Convert Date Columns (If Exists)
# This enables trend & earthquake impact visualization later.

# %%
# Example — rename based on your actual column names:
# housing.rename(columns={"Tarih":"Date"}, inplace=True)
# housing['Date'] = pd.to_datetime(housing['Date'])
# housing.sort_values('Date', inplace=True)

# %% [markdown]
# ## 4. (Later Step) Time Series Visualization
# This section will show housing trend + mark earthquake dates.
#
# ---
# ### Example code (will be activated when column names added):
# ```python
# plt.figure(figsize=(12,4))
# plt.plot(housing['Date'], housing['Sales'], linewidth=2)
# plt.title('Housing Sales Over Time')
# plt.axvline(pd.to_datetime('2017-08-12'), color='red')  # example earthquake line
# plt.show()
# ```
# ---

# %% [markdown]
# ## Notebook Ready for Analysis
# From here you will proceed to:
# 1. Merge earthquake + sales timelines
# 2. Pre/Post shock comparison
# 3. Hypothesis tests (`t-test`, Mann Whitney, etc.)
# 4. Final results + visual summaries
#
# Next file suggestion:
# **`notebooks/02_hypothesis-testing.ipynb`**
